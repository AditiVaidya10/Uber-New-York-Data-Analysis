# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
uber_15=pd.read_csv(r'/Users/test/Downloads/uber-pickups-in-new-york-city/uber-raw-data-janjune-15.csv', encoding='utf-8')
uber_15['Pickup_date']=pd.to_datetime(uber_15['Pickup_date'], format = '%Y-%m-%d %H:%M:%S')
uber_15['weekday']=uber_15['Pickup_date'].dt.day_name()
uber_15['day']=uber_15['Pickup_date'].dt.day
uber_15['hour']=uber_15['Pickup_date'].dt.hour
uber_15['month']=uber_15['Pickup_date'].dt.month
uber_15['minute']=uber_15['Pickup_date'].dt.minute
temp=uber_15.groupby(['month','weekday'],as_index=False).size()
dict_month={1: 'Jan', 2:'Feb', 3:'Mar', 4:'Apr', 5:'May', 6:'Jun', 7:'Jul', 8:'Aug', 9:'Sept', 10:'Oct', 11:'Nov', 12:'Dec'}

# %%
uber_15.groupby(['weekday','hour']).count()
# Out:
#                 Dispatching_base_num  Pickup_date  Affiliated_base_num  \
# weekday   hour
# Friday    0                    85939        85939                84994
#           1                    46616        46616                46114
#           2                    28102        28102                27790
#           3                    19518        19518                19285
#           4                    23575        23575                23322
# ...                              ...          ...                  ...
# Wednesday 19                  143751       143751               142143
#           20                  136003       136003               134525
#           21                  133993       133993               132556
#           22                  127026       127026               125719
#           23                   99490        99490                98597
#
#                 locationID     day   month  minute
# weekday   hour
# Friday    0          85939   85939   85939   85939
#           1          46616   46616   46616   46616
#           2          28102   28102   28102   28102
#           3          19518   19518   19518   19518
#           4          23575   23575   23575   23575
# ...                    ...     ...     ...     ...
# Wednesday 19        143751  143751  143751  143751
#           20        136003  136003  136003  136003
#           21        133993  133993  133993  133993
#           22        127026  127026  127026  127026
#           23         99490   99490   99490   99490
#
# [168 rows x 7 columns]

# %%
summary=uber_15.groupby(['weekday','hour'],as_index=False).size()

# %%
plt.figure(figsize=(12,8))
sns.pointplot(x='hour', y='size', hue='weekday', data=summary)
# Out:
# <AxesSubplot:xlabel='hour', ylabel='size'>
